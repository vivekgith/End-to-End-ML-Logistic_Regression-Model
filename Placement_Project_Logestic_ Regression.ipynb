# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
x.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 19   5.2  132.0
# 80   4.9  196.0
# 34   4.8  163.0
# 20   6.6  120.0
# 5    7.1   48.0
# ..   ...    ...
# 77   7.3   50.0
# 35   6.8   90.0
# 47   5.2  161.0
# 44   7.5   61.0
# 46   5.3  114.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 19    0
# 80    0
# 34    0
# 20    1
# 5     1
#      ..
# 77    1
# 35    1
# 47    0
# 44    1
# 46    0
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[-0.69082025,  0.13999223],
#        [-0.94703105,  1.78561517],
#        [-1.03243466,  0.93709084],
#        [ 0.50483018, -0.16856207],
#        [ 0.93184819, -2.01988788],
#        [ 2.12749862, -0.16856207],
#        [-1.45945267,  1.8884666 ],
#        [ 1.3588662 ,  0.0371408 ],
#        [ 0.41942658, -2.30272932],
#        [-0.09299503, -0.52854209],
#        [ 0.84644459,  0.31998224],
#        [-1.71566347, -1.3256407 ],
#        [-1.03243466, -0.37426494],
#        [ 0.67563739, -0.0914235 ],
#        [-0.17839864,  1.01422942],
#        [ 1.1026554 , -0.27141351],
#        [-0.52001304,  0.31998224],
#        [ 0.76104099,  0.31998224],
#        [ 0.67563739,  0.37140796],
#        [-0.86162745, -0.21998779],
#        [ 1.1026554 ,  0.26855652],
#        [-1.03243466,  1.09136799],
#        [-0.94703105,  0.19141795],
#        [ 0.24861938,  0.01142794],
#        [ 0.16321577, -0.34855208],
#        [ 0.24861938,  0.0371408 ],
#        [-0.94703105, -0.16856207],
#        [ 0.41942658,  0.08856651],
#        [ 0.07781217, -1.58276929],
#        [-1.11783826, -1.91703645],
#        [-1.11783826, -1.0170864 ],
#        [-0.77622385,  0.0371408 ],
#        [-0.77622385, -1.55705643],
#        [-0.77622385,  1.271358  ],
#        [-0.69082025, -0.93994782],
#        [-2.31348869,  1.45134801],
#        [ 0.41942658,  0.85995227],
#        [-0.26380224,  0.42283367],
#        [-0.00759143,  0.57711082],
#        [-1.37404907, -2.17416503],
#        [-1.03243466,  0.37140796],
#        [-1.80106708, -0.45140351],
#        [ 0.84644459, -0.37426494],
#        [ 0.59023378,  0.70567511],
#        [ 1.2734626 ,  0.08856651],
#        [ 0.84644459,  1.86275374],
#        [ 0.33402298, -0.27141351],
#        [ 0.67563739, -0.37426494],
#        [-0.17839864,  0.39712081],
#        [-0.26380224,  0.3456951 ],
#        [ 0.07781217,  0.13999223],
#        [ 0.07781217, -1.17136355],
#        [-0.69082025, -0.42569066],
#        [-1.20324186,  0.49997225],
#        [-0.52001304, -0.32283922],
#        [ 1.1026554 , -1.04279926],
#        [-1.11783826, -0.14284921],
#        [-0.94703105,  0.73138797],
#        [-0.86162745, -0.91423497],
#        [-1.37404907,  0.57711082],
#        [-2.14268148,  2.73699093],
#        [ 0.24861938, -0.60568067],
#        [ 1.70048061, -1.22278927],
#        [ 0.59023378,  1.42563515],
#        [ 1.52967341, -0.32283922],
#        [ 0.76104099, -0.78567067],
#        [ 1.78588421,  1.01422942],
#        [ 1.78588421,  0.57711082],
#        [ 0.84644459,  1.24564514],
#        [-0.69082025,  2.5055752 ],
#        [-0.00759143, -0.06571064],
#        [ 0.93184819,  0.62853654],
#        [ 0.33402298,  0.37140796],
#        [ 0.84644459, -1.60848214],
#        [-0.52001304,  0.2171308 ],
#        [ 1.2734626 ,  0.80852655],
#        [ 1.95669142,  1.06565513],
#        [-1.71566347, -0.68281924],
#        [-0.60541665, -0.14284921],
#        [ 1.188059  ,  0.13999223],
#        [ 0.41942658, -0.93994782],
#        [-0.52001304, -0.50282923],
#        [-0.26380224,  1.09136799],
#        [ 0.50483018,  0.29426938],
#        [ 0.76104099,  0.29426938],
#        [ 1.1026554 , -1.96846216],
#        [ 0.67563739, -0.93994782],
#        [-0.69082025,  0.88566512],
#        [ 1.2734626 , -1.68562072],
#        [-0.60541665, -0.32283922]])

# %%
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[-0.86162745, -1.634195  ],
#        [-0.00759143, -0.63139352],
#        [ 0.07781217, -0.60568067],
#        [-0.00759143, -1.55705643],
#        [ 1.3588662 , -0.96566068],
#        [-0.26380224,  0.13999223],
#        [-0.94703105,  0.62853654],
#        [-0.94703105, -1.68562072],
#        [-0.00759143, -2.09702645],
#        [ 0.07781217,  0.75710083]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %% [markdown]
# # Model Training

# %%
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)

# %%
y_test
# Out:
# 7     0
# 62    0
# 14    0
# 45    1
# 42    1
# 87    1
# 89    0
# 73    0
# 10    1
# 8     0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.5

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting scipy>=1.16.3 (from mlxtend)
#   Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting numpy>=2.3.5 (from mlxtend)
#   Downloading numpy-2.4.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting pandas>=2.3.3 (from mlxtend)
#   Downloading pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting scikit-learn>=1.8.0 (from mlxtend)
#   Downloading scikit_learn-1.8.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Collecting matplotlib>=3.10.8 (from mlxtend)
#   Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting joblib>=1.5.2 (from mlxtend)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.13/site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.3.3->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.13/site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /opt/anaconda3/lib/python3.13/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Downloading mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 23.3 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 4.9 MB/s eta 0:00:00 MB/s eta 0:00:01:01m
# Downloading numpy-2.4.0-cp313-cp313-macosx_14_0_arm64.whl (5.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 4.4 MB/s eta 0:00:00 MB/s eta 0:00:01
# Downloading pandas-2.3.3-cp313-cp313-macosx_11_0_arm64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 5.0 MB/s eta 0:00:00 MB/s eta 0:00:0101
# Downloading scikit_learn-1.8.0-cp313-cp313-macosx_12_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 3.7 MB/s eta 0:00:003.7 MB/s eta 0:00:01
# Downloading scipy-1.16.3-cp313-cp313-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 5.2 MB/s eta 0:00:005.2 MB/s eta 0:00:01
# Installing collected packages: numpy, joblib, scipy, pandas, scikit-learn, matplotlib, mlxtend
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: joblib━━━━━━━━━━━━━━━━━━━━━━━━ 0/7 [numpy]
#     Found existing installation: joblib 1.4.2━━━━━ 0/7 [numpy]
#     Uninstalling joblib-1.4.2:━━━━━━━━━━━━━━━━━━━━ 0/7 [numpy]
#       Successfully uninstalled joblib-1.4.2━━━━━━━ 0/7 [numpy]
#   Attempting uninstall: scipym╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [joblib]
#     Found existing installation: scipy 1.15.3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/7 [joblib]
#     Uninstalling scipy-1.15.3:━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/7 [scipy]lib]
#       Successfully uninstalled scipy-1.15.3╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/7 [scipy]
#   Attempting uninstall: pandas━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/7 [scipy]
#     Found existing installation: pandas 2.2.3━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/7 [scipy]
#     Uninstalling pandas-2.2.3:━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pandas]
#       Successfully uninstalled pandas-2.2.35;237m╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pandas]
#   Attempting uninstall: scikit-learn━━╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pandas]
#     Found existing installation: scikit-learn 1.6.1━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pandas]
#     Uninstalling scikit-learn-1.6.1:0m╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pandas]
#       Successfully uninstalled scikit-learn-1.6.1╺━━━━━━━━━━━━━━━━━━━━━━ 3/7 [pandas]
#   Attempting uninstall: matplotlib━━━━━━━━━╸━━━━━━━━━━━━━━━━━ 4/7 [scikit-learn]
#     Found existing installation: matplotlib 3.10.0249;38;114m╸━━━━━━━━━━━━━━━━━ 4/7 [scikit-learn]
#     Uninstalling matplotlib-3.10.0:━━━━━━━━━━━━━━╸━━━━━━━━━━━ 5/7 [matplotlib]
#       Successfully uninstalled matplotlib-3.10.0━╸━━━━━━━━━━━ 5/7 [matplotlib]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [mlxtend]━━━ 6/7 [mlxtend]atplotlib]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# numba 0.61.0 requires numpy<2.2,>=1.24, but you have numpy 2.4.0 which is incompatible.
# sklearn-compat 0.1.3 requires scikit-learn<1.7,>=1.2, but you have scikit-learn 1.8.0 which is incompatible.
# Successfully installed joblib-1.5.3 matplotlib-3.10.8 mlxtend-0.24.0 numpy-2.4.0 pandas-2.3.3 scikit-learn-1.8.0 scipy-1.16.3

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
